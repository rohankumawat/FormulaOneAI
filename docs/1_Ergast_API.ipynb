# %% [markdown]
# # Ergast API Exploration 🏎️
#
# Welcome to the first instructional notebook on the Ergast API, your gateway to a wealth of Formula 1 data. This notebook is designed to introduce you to the Ergast API's endpoints, offering a clear overview and practical examples to kickstart your data extraction journey. Perfect for analysts, developers, or any F1 enthusiast out there, this guide is your first step towards harnessing the power of F1 data. Dive into the examples, explore the endpoints, and start your data-driven exploration today!
#
# ## Table of Contents
#
# 1. [Import Required Libraries](#import-required-libraries)
# 2. [Circuits Endpoint](#circuits-endpoint)
# 3. [Constructors Endpoint](#constructors-endpoint)
# 4. [Driver Endpoint](#driver-endpoint)
# 5. [Seasons Endpoint](#seasons-endpoint)

# %% [markdown]
# ## 1. [Import Required Libraries](#import-required-libraries)

# %%
import requests
import json
import pandas as pd
import xml.etree.ElementTree as ET
# Out:
# /Users/dazzpool/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ## 2. [Circuits Endpoint](#circuit-endpoint)

# %%
# URL for the circuits endpoint
url = "http://ergast.com/api/f1/circuits.json"

# %%
# Make a GET request to the Ergast API
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON data from the response
    circuits_data = response.json()
    # Print the data
    print(json.dumps(circuits_data, indent = 4))
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# {
#     "MRData": {
#         "xmlns": "http://ergast.com/mrd/1.5",
#         "series": "f1",
#         "url": "http://ergast.com/api/f1/circuits.json",
#         "limit": "30",
#         "offset": "0",
#         "total": "77",
#         "CircuitTable": {
#             "Circuits": [
#                 {
#                     "circuitId": "adelaide",
#                     "url": "http://en.wikipedia.org/wiki/Adelaide_Street_Circuit",
#                     "circuitName": "Adelaide Street Circuit",
#                     "Location": {
#                         "lat": "-34.9272",
#                         "long": "138.617",
#                         "locality": "Adelaide",
#                         "country": "Australia"
#                     }
#                 },
#                 {
#                     "circuitId": "ain-diab",
#                     "url": "http://en.wikipedia.org/wiki/Ain-Diab_Circuit",
#                     "circuitName": "Ain Diab",
#                     "Location": {
#                         "lat": "33.5786",
#                         "long": "-7.6875",
#                         "locality": "Casablanca",
#                         "country": "Morocco"
#                     }
#                 },
#                 {
#                     "circuitId": "aintree",
#                     "url": "http://en.wikipedia.org/wiki/Aintree_Motor_Racing_Circuit",
#                     "circuitName": "Aintree",
#                     "Location": {
#                         "lat": "53.4769",
#                         "long": "-2.94056",
#                         "locality": "Liverpool",
#                         "country": "UK"
#                     }
#                 },
#                 {
#                     "circuitId": "albert_park",
#                     "url": "http://en.wikipedia.org/wiki/Melbourne_Grand_Prix_Circuit",
#                     "circuitName": "Albert Park Grand Prix Circuit",
#                     "Location": {
#                         "lat": "-37.8497",
#                         "long": "144.968",
#                         "locality": "Melbourne",
#                         "country": "Australia"
#                     }
#                 },
#                 {
#                     "circuitId": "americas",
#                     "url": "http://en.wikipedia.org/wiki/Circuit_of_the_Americas",
#                     "circuitName": "Circuit of the Americas",
#                     "Location": {
#                         "lat": "30.1328",
#                         "long": "-97.6411",
#                         "locality": "Austin",
#                         "country": "USA"
#                     }
#                 },
#                 {
#                     "circuitId": "anderstorp",
#                     "url": "http://en.wikipedia.org/wiki/Scandinavian_Raceway",
#                     "circuitName": "Scandinavian Raceway",
#                     "Location": {
#                         "lat": "57.2653",
#                         "long": "13.6042",
#                         "locality": "Anderstorp",
#                         "country": "Sweden"
#                     }
#                 },
#                 {
#                     "circuitId": "avus",
#                     "url": "http://en.wikipedia.org/wiki/AVUS",
#                     "circuitName": "AVUS",
#                     "Location": {
#                         "lat": "52.4806",
#                         "long": "13.2514",
#                         "locality": "Berlin",
#                         "country": "Germany"
#                     }
#                 },
#                 {
#                     "circuitId": "bahrain",
#                     "url": "http://en.wikipedia.org/wiki/Bahrain_International_Circuit",
#                     "circuitName": "Bahrain International Circuit",
#                     "Location": {
#                         "lat": "26.0325",
#                         "long": "50.5106",
#                         "locality": "Sakhir",
#                         "country": "Bahrain"
#                     }
#                 },
#                 {
#                     "circuitId": "baku",
#                     "url": "http://en.wikipedia.org/wiki/Baku_City_Circuit",
#                     "circuitName": "Baku City Circuit",
#                     "Location": {
#                         "lat": "40.3725",
#                         "long": "49.8533",
#                         "locality": "Baku",
#                         "country": "Azerbaijan"
#                     }
#                 },
#                 {
#                     "circuitId": "boavista",
#                     "url": "http://en.wikipedia.org/wiki/Circuito_da_Boavista",
#                     "circuitName": "Circuito da Boavista",
#                     "Location": {
#                         "lat": "41.1705",
#                         "long": "-8.67325",
#                         "locality": "Oporto",
#                         "country": "Portugal"
#                     }
#                 },
#                 {
#                     "circuitId": "brands_hatch",
#                     "url": "http://en.wikipedia.org/wiki/Brands_Hatch",
#                     "circuitName": "Brands Hatch",
#                     "Location": {
#                         "lat": "51.3569",
#                         "long": "0.263056",
#                         "locality": "Kent",
#                         "country": "UK"
#                     }
#                 },
#                 {
#                     "circuitId": "bremgarten",
#                     "url": "http://en.wikipedia.org/wiki/Circuit_Bremgarten",
#                     "circuitName": "Circuit Bremgarten",
#                     "Location": {
#                         "lat": "46.9589",
#                         "long": "7.40194",
#                         "locality": "Bern",
#                         "country": "Switzerland"
#                     }
#                 },
#                 {
#                     "circuitId": "buddh",
#                     "url": "http://en.wikipedia.org/wiki/Buddh_International_Circuit",
#                     "circuitName": "Buddh International Circuit",
#                     "Location": {
#                         "lat": "28.3487",
#                         "long": "77.5331",
#                         "locality": "Uttar Pradesh",
#                         "country": "India"
#                     }
#                 },
#                 {
#                     "circuitId": "catalunya",
#                     "url": "http://en.wikipedia.org/wiki/Circuit_de_Barcelona-Catalunya",
#                     "circuitName": "Circuit de Barcelona-Catalunya",
#                     "Location": {
#                         "lat": "41.57",
#                         "long": "2.26111",
#                         "locality": "Montmel\u00f3",
#                         "country": "Spain"
#                     }
#                 },
#                 {
#                     "circuitId": "charade",
#                     "url": "http://en.wikipedia.org/wiki/Charade_Circuit",
#                     "circuitName": "Charade Circuit",
#                     "Location": {
#                         "lat": "45.7472",
#                         "long": "3.03889",
#                         "locality": "Clermont-Ferrand",
#                         "country": "France"
#                     }
#                 },
#                 {
#                     "circuitId": "dallas",
#                     "url": "http://en.wikipedia.org/wiki/Fair_Park",
#                     "circuitName": "Fair Park",
#                     "Location": {
#                         "lat": "32.7774",
#                         "long": "-96.7587",
#                         "locality": "Dallas",
#                         "country": "USA"
#                     }
#                 },
#                 {
#                     "circuitId": "detroit",
#                     "url": "http://en.wikipedia.org/wiki/Detroit_street_circuit",
#                     "circuitName": "Detroit Street Circuit",
#                     "Location": {
#                         "lat": "42.3298",
#                         "long": "-83.0401",
#                         "locality": "Detroit",
#                         "country": "USA"
#                     }
#                 },
#                 {
#                     "circuitId": "dijon",
#                     "url": "http://en.wikipedia.org/wiki/Dijon-Prenois",
#                     "circuitName": "Dijon-Prenois",
#                     "Location": {
#                         "lat": "47.3625",
#                         "long": "4.89913",
#                         "locality": "Dijon",
#                         "country": "France"
#                     }
#                 },
#                 {
#                     "circuitId": "donington",
#                     "url": "http://en.wikipedia.org/wiki/Donington_Park",
#                     "circuitName": "Donington Park",
#                     "Location": {
#                         "lat": "52.8306",
#                         "long": "-1.37528",
#                         "locality": "Castle Donington",
#                         "country": "UK"
#                     }
#                 },
#                 {
#                     "circuitId": "essarts",
#                     "url": "http://en.wikipedia.org/wiki/Rouen-Les-Essarts",
#                     "circuitName": "Rouen-Les-Essarts",
#                     "Location": {
#                         "lat": "49.3306",
#                         "long": "1.00458",
#                         "locality": "Rouen",
#                         "country": "France"
#                     }
#                 },
#                 {
#                     "circuitId": "estoril",
#                     "url": "http://en.wikipedia.org/wiki/Aut%C3%B3dromo_do_Estoril",
#                     "circuitName": "Aut\u00f3dromo do Estoril",
#                     "Location": {
#                         "lat": "38.7506",
#                         "long": "-9.39417",
#                         "locality": "Estoril",
#                         "country": "Portugal"
#                     }
#                 },
#                 {
#                     "circuitId": "fuji",
#                     "url": "http://en.wikipedia.org/wiki/Fuji_Speedway",
#                     "circuitName": "Fuji Speedway",
#                     "Location": {
#                         "lat": "35.3717",
#                         "long": "138.927",
#                         "locality": "Oyama",
#                         "country": "Japan"
#                     }
#                 },
#                 {
#                     "circuitId": "galvez",
#                     "url": "http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Oscar_Alfredo_G%C3%A1lvez",
#                     "circuitName": "Aut\u00f3dromo Juan y Oscar G\u00e1lvez",
#                     "Location": {
#                         "lat": "-34.6943",
#                         "long": "-58.4593",
#                         "locality": "Buenos Aires",
#                         "country": "Argentina"
#                     }
#                 },
#                 {
#                     "circuitId": "george",
#                     "url": "http://en.wikipedia.org/wiki/Prince_George_Circuit",
#                     "circuitName": "Prince George Circuit",
#                     "Location": {
#                         "lat": "-33.0486",
#                         "long": "27.8736",
#                         "locality": "Eastern Cape Province",
#                         "country": "South Africa"
#                     }
#                 },
#                 {
#                     "circuitId": "hockenheimring",
#                     "url": "http://en.wikipedia.org/wiki/Hockenheimring",
#                     "circuitName": "Hockenheimring",
#                     "Location": {
#                         "lat": "49.3278",
#                         "long": "8.56583",
#                         "locality": "Hockenheim",
#                         "country": "Germany"
#                     }
#                 },
#                 {
#                     "circuitId": "hungaroring",
#                     "url": "http://en.wikipedia.org/wiki/Hungaroring",
#                     "circuitName": "Hungaroring",
#                     "Location": {
#                         "lat": "47.5789",
#                         "long": "19.2486",
#                         "locality": "Budapest",
#                         "country": "Hungary"
#                     }
#                 },
#                 {
#                     "circuitId": "imola",
#                     "url": "http://en.wikipedia.org/wiki/Autodromo_Enzo_e_Dino_Ferrari",
#                     "circuitName": "Autodromo Enzo e Dino Ferrari",
#                     "Location": {
#                         "lat": "44.3439",
#                         "long": "11.7167",
#                         "locality": "Imola",
#                         "country": "Italy"
#                     }
#                 },
#                 {
#                     "circuitId": "indianapolis",
#                     "url": "http://en.wikipedia.org/wiki/Indianapolis_Motor_Speedway",
#                     "circuitName": "Indianapolis Motor Speedway",
#                     "Location": {
#                         "lat": "39.795",
#                         "long": "-86.2347",
#                         "locality": "Indianapolis",
#                         "country": "USA"
#                     }
#                 },
#                 {
#                     "circuitId": "interlagos",
#                     "url": "http://en.wikipedia.org/wiki/Aut%C3%B3dromo_Jos%C3%A9_Carlos_Pace",
#                     "circuitName": "Aut\u00f3dromo Jos\u00e9 Carlos Pace",
#                     "Location": {
#                         "lat": "-23.7036",
#                         "long": "-46.6997",
#                         "locality": "S\u00e3o Paulo",
#                         "country": "Brazil"
#                     }
#                 },
#                 {
#                     "circuitId": "istanbul",
#                     "url": "http://en.wikipedia.org/wiki/Istanbul_Park",
#                     "circuitName": "Istanbul Park",
#                     "Location": {
#                         "lat": "40.9517",
#                         "long": "29.405",
#                         "locality": "Istanbul",
#                         "country": "Turkey"
#                     }
#                 }
#             ]
#         }
#     }
# }

# %%
# Display the type of the stored data and its keys to understand its structure
if circuits_data:
    print(type(circuits_data))
    print(circuits_data.keys())
# Out:
# <class 'dict'>
# dict_keys(['MRData'])

# %%
# Display the type of the stored data and its keys to understand its structure
if circuits_data:
    print(circuits_data['MRData']['CircuitTable']['Circuits'][:2]) # display the first 2 circuits for a sneak peek
else:
    print("No data to display")
# Out:
# [{'circuitId': 'adelaide', 'url': 'http://en.wikipedia.org/wiki/Adelaide_Street_Circuit', 'circuitName': 'Adelaide Street Circuit', 'Location': {'lat': '-34.9272', 'long': '138.617', 'locality': 'Adelaide', 'country': 'Australia'}}, {'circuitId': 'ain-diab', 'url': 'http://en.wikipedia.org/wiki/Ain-Diab_Circuit', 'circuitName': 'Ain Diab', 'Location': {'lat': '33.5786', 'long': '-7.6875', 'locality': 'Casablanca', 'country': 'Morocco'}}]

# %%
# Check if the data was successfully retrieved
if circuits_data:
    # Convert the circuits data to a DataFrame
    circuits_df = pd.json_normalize(circuits_data['MRData']['CircuitTable']['Circuits'])
    
    # Define the file path where the CSV will be saved
    csv_file_path = '../data/circuits_data.csv'
    
    # Save the DataFrame to a CSV file
    circuits_df.to_csv(csv_file_path, index=False)
    print(f"Circuits data successfully saved to {csv_file_path}")
else:
    print("No data to save")
# Out:
# Circuits data successfully saved to ../data/circuits_data.csv

# %%
circuits_df.head()
# Out:
#      circuitId                                                url  \
# 0     adelaide  http://en.wikipedia.org/wiki/Adelaide_Street_C...
# 1     ain-diab      http://en.wikipedia.org/wiki/Ain-Diab_Circuit
# 2      aintree  http://en.wikipedia.org/wiki/Aintree_Motor_Rac...
# 3  albert_park  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 4     americas  http://en.wikipedia.org/wiki/Circuit_of_the_Am...
#
#                       circuitName Location.lat Location.long  \
# 0         Adelaide Street Circuit     -34.9272       138.617
# 1                        Ain Diab      33.5786       -7.6875
# 2                         Aintree      53.4769      -2.94056
# 3  Albert Park Grand Prix Circuit     -37.8497       144.968
# 4         Circuit of the Americas      30.1328      -97.6411
#
#   Location.locality Location.country
# 0          Adelaide        Australia
# 1        Casablanca          Morocco
# 2         Liverpool               UK
# 3         Melbourne        Australia
# 4            Austin              USA

# %%
circuits_2010_url = "http://ergast.com/api/f1/2010/circuits"
# Make a GET request to the Ergast API
response = requests.get(circuits_2010_url)
# Check if the request was successful
if response.status_code == 200:
    circuits_2010_data = response.json()
else:
    print(f"Failed to retrieve data: {response.status_code}")
    circuits_2010_data = None

# Display the type of the stored data and its keys to understand its structure
if circuits_2010_data:
    print(type(circuits_2010_data))
    print(circuits_2010_data.keys())
    # Show a snippet of the data for exploration
    print(circuits_2010_data['MRData']['CircuitTable']['Circuits'][:2])  # Display the first 2 circuits for a sneak peek
else:
    print("No data to display")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 6
#       4 # Check if the request was successful
#       5 if response.status_code == 200:
# ----> 6     circuits_2010_data = response.json()
#       7 else:
#       8     print(f"Failed to retrieve data: {response.status_code}")
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
circuits_2010_url = "http://ergast.com/api/f1/2010/circuits.xml"
response = requests.get(circuits_2010_url)

# Check if the request was successful
if response.status_code == 200:
    # Print the beginning of the raw XML response
    print(response.text[:500])  # Increase the number if needed

    # Parse the XML response
    root = ET.fromstring(response.content)

    # Print root tag and namespace (temporary, for debugging)
    print(root.tag)

    # Define the namespace (adjust based on the printed root tag)
    ns = {'mrd': 'YOUR_NAMESPACE_URL_HERE'}

    # Find all Circuit elements (adjust tag and namespace if needed)
    circuits = root.findall('.//mrd:Circuit', ns)
    
    # Check if circuits were found
    if circuits:
        # Extract data for each circuit
        for circuit in circuits:
            circuit_id = circuit.attrib['circuitId']
            circuit_name = circuit.find('mrd:CircuitName', ns).text
            location = circuit.find('mrd:Location', ns)
            locality = location.find('mrd:Locality', ns).text
            country = location.find('mrd:Country', ns).text

            # Print each circuit's details
            print(f"Circuit ID: {circuit_id}")
            print(f"Circuit Name: {circuit_name}")
            print(f"Locality: {locality}")
            print(f"Country: {country}")
            print('---')
    else:
        print("No circuits found. Check the XML structure and namespace.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <?xml-stylesheet type="text/xsl" href="/schemas/mrd-1.5.xsl"?>
# <MRData xmlns="http://ergast.com/mrd/1.5" series="f1" url="http://ergast.com/api/f1/2010/circuits.xml" limit="30" offset="0" total="19">
# 	<CircuitTable season="2010">
# 		<Circuit circuitId="albert_park" url="http://en.wikipedia.org/wiki/Melbourne_Grand_Prix_Circuit">
# 			<CircuitName>Albert Park Grand Prix Circuit</CircuitName>
# 			<Location lat="-37.8497" long="144.968">
# 				<Locality>Melbourne</L
# {http://ergast.com/mrd/1.5}MRData
# No circuits found. Check the XML structure and namespace.

# %%
import xml.etree.ElementTree as ET
import requests

circuits_2010_url = "http://ergast.com/api/f1/2010/circuits.xml"
response = requests.get(circuits_2010_url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the XML response
    root = ET.fromstring(response.content)

    # Define the namespace
    ns = {'mrd': 'http://ergast.com/mrd/1.5'}

    # Find all Circuit elements
    circuits = root.findall('.//mrd:Circuit', ns)
    
    # Check if circuits were found
    if circuits:
        # Extract data for each circuit
        for circuit in circuits:
            circuit_id = circuit.attrib['circuitId']
            circuit_name = circuit.find('mrd:CircuitName', ns).text
            location = circuit.find('mrd:Location', ns)
            locality = location.find('mrd:Locality', ns).text
            country = location.find('mrd:Country', ns).text

            # Print each circuit's details
            print(f"Circuit ID: {circuit_id}")
            print(f"Circuit Name: {circuit_name}")
            print(f"Locality: {locality}")
            print(f"Country: {country}")
            print('---')
    else:
        print("No circuits found. Check the XML structure and namespace.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# Circuit ID: albert_park
# Circuit Name: Albert Park Grand Prix Circuit
# Locality: Melbourne
# Country: Australia
# ---
# Circuit ID: bahrain
# Circuit Name: Bahrain International Circuit
# Locality: Sakhir
# Country: Bahrain
# ---
# Circuit ID: catalunya
# Circuit Name: Circuit de Barcelona-Catalunya
# Locality: Montmeló
# Country: Spain
# ---
# Circuit ID: hockenheimring
# Circuit Name: Hockenheimring
# Locality: Hockenheim
# Country: Germany
# ---
# Circuit ID: hungaroring
# Circuit Name: Hungaroring
# Locality: Budapest
# Country: Hungary
# ---
# Circuit ID: interlagos
# Circuit Name: Autódromo José Carlos Pace
# Locality: São Paulo
# Country: Brazil
# ---
# Circuit ID: istanbul
# Circuit Name: Istanbul Park
# Locality: Istanbul
# Country: Turkey
# ---
# Circuit ID: marina_bay
# Circuit Name: Marina Bay Street Circuit
# Locality: Marina Bay
# Country: Singapore
# ---
# Circuit ID: monaco
# Circuit Name: Circuit de Monaco
# Locality: Monte-Carlo
# Country: Monaco
# ---
# Circuit ID: monza
# Circuit Name: Autodromo Nazionale di Monza
# Locality: Monza
# Country: Italy
# ---
# Circuit ID: sepang
# Circuit Name: Sepang International Circuit
# Locality: Kuala Lumpur
# Country: Malaysia
# ---
# Circuit ID: shanghai
# Circuit Name: Shanghai International Circuit
# Locality: Shanghai
# Country: China
# ---
# Circuit ID: silverstone
# Circuit Name: Silverstone Circuit
# Locality: Silverstone
# Country: UK
# ---
# Circuit ID: spa
# Circuit Name: Circuit de Spa-Francorchamps
# Locality: Spa
# Country: Belgium
# ---
# Circuit ID: suzuka
# Circuit Name: Suzuka Circuit
# Locality: Suzuka
# Country: Japan
# ---
# Circuit ID: valencia
# Circuit Name: Valencia Street Circuit
# Locality: Valencia
# Country: Spain
# ---
# Circuit ID: villeneuve
# Circuit Name: Circuit Gilles Villeneuve
# Locality: Montreal
# Country: Canada
# ---
# Circuit ID: yas_marina
# Circuit Name: Yas Marina Circuit
# Locality: Abu Dhabi
# Country: UAE
# ---
# Circuit ID: yeongam
# Circuit Name: Korean International Circuit
# Locality: Yeongam County
# Country: Korea
# ---

# %% [markdown]
# ## 3. [Constructors Endpoint](#constructors-endpoint)

# %%
url = "http://ergast.com/api/f1/constructors"

# %%
# Make a GET request to the Ergast API
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON data from the response
    constructors_data = response.json()
    # Print the data
    print(json.dumps(constructors_data, indent = 4))
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[14], line 4
#       1 # Check if the request was successful
#       2 if response.status_code == 200:
#       3     # Parse the JSON data from the response
# ----> 4     constructors_data = response.json()
#       5     # Print the data
#       6     print(json.dumps(constructors_data, indent = 4))
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Print the beginning of the raw XML response
    print(response.text[:1000])  # Increase the number if needed
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <?xml-stylesheet type="text/xsl" href="/schemas/mrd-1.5.xsl"?>
# <MRData xmlns="http://ergast.com/mrd/1.5" series="f1" url="http://ergast.com/api/f1/constructors" limit="30" offset="0" total="211">
# 	<ConstructorTable>
# 		<Constructor constructorId="adams" url="http://en.wikipedia.org/wiki/Adams_(constructor)">
# 			<Name>Adams</Name>
# 			<Nationality>American</Nationality>
# 		</Constructor>
# 		<Constructor constructorId="afm" url="http://en.wikipedia.org/wiki/Alex_von_Falkenhausen_Motorenbau">
# 			<Name>AFM</Name>
# 			<Nationality>German</Nationality>
# 		</Constructor>
# 		<Constructor constructorId="ags" url="http://en.wikipedia.org/wiki/Automobiles_Gonfaronnaises_Sportives">
# 			<Name>AGS</Name>
# 			<Nationality>French</Nationality>
# 		</Constructor>
# 		<Constructor constructorId="alfa" url="http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One">
# 			<Name>Alfa Romeo</Name>
# 			<Nationality>Swiss</Nationality>
# 		</Constructor>
# 		<Constructor constructorId="alphat

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the XML response
    root = ET.fromstring(response.content)

    # Define the namespace
    ns = {'mrd': 'http://ergast.com/mrd/1.5'}

    # Find all Circuit elements
    constructors = root.findall('.//mrd:Constructor', ns)
    
    # Check if circuits were found
    if constructors:
        # Extract data for each circuit
        for constructor in constructors:
            constructor_id = constructor.attrib['constructorId']
            constructor_name = constructor.find('mrd:Name', ns).text
            nationality = constructor.find('mrd:Nationality', ns).text
            constructor_information = constructor.attrib['url']

            # Print each constructor's details
            print(f"Constructor ID: {constructor_id}")
            print(f"Constructor Name: {constructor_name}")
            print(f"Nationality: {nationality}")
            print(f"Constructor Information: {constructor_information}")
            print('---')
    else:
        print("No circuits found. Check the XML structure and namespace.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# Constructor ID: adams
# Constructor Name: Adams
# Nationality: American
# Constructor Information: http://en.wikipedia.org/wiki/Adams_(constructor)
# ---
# Constructor ID: afm
# Constructor Name: AFM
# Nationality: German
# Constructor Information: http://en.wikipedia.org/wiki/Alex_von_Falkenhausen_Motorenbau
# ---
# Constructor ID: ags
# Constructor Name: AGS
# Nationality: French
# Constructor Information: http://en.wikipedia.org/wiki/Automobiles_Gonfaronnaises_Sportives
# ---
# Constructor ID: alfa
# Constructor Name: Alfa Romeo
# Nationality: Swiss
# Constructor Information: http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One
# ---
# Constructor ID: alphatauri
# Constructor Name: AlphaTauri
# Nationality: Italian
# Constructor Information: http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# ---
# Constructor ID: alpine
# Constructor Name: Alpine F1 Team
# Nationality: French
# Constructor Information: http://en.wikipedia.org/wiki/Alpine_F1_Team
# ---
# Constructor ID: alta
# Constructor Name: Alta
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Alta_auto_racing_team
# ---
# Constructor ID: amon
# Constructor Name: Amon
# Nationality: New Zealander
# Constructor Information: http://en.wikipedia.org/wiki/Amon_(Formula_One_team)
# ---
# Constructor ID: moda
# Constructor Name: Andrea Moda
# Nationality: Italian
# Constructor Information: http://en.wikipedia.org/wiki/Andrea_Moda_Formula
# ---
# Constructor ID: apollon
# Constructor Name: Apollon
# Nationality: Swiss
# Constructor Information: http://en.wikipedia.org/wiki/Apollon_(Formula_One)
# ---
# Constructor ID: arrows
# Constructor Name: Arrows
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Arrows_Grand_Prix_International
# ---
# Constructor ID: arzani-volpini
# Constructor Name: Arzani-Volpini
# Nationality: Italian
# Constructor Information: http://en.wikipedia.org/wiki/Arzani-Volpini
# ---
# Constructor ID: butterworth
# Constructor Name: Aston Butterworth
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Aston_Butterworth
# ---
# Constructor ID: aston_martin
# Constructor Name: Aston Martin
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One
# ---
# Constructor ID: ats
# Constructor Name: ATS
# Nationality: Italian
# Constructor Information: http://en.wikipedia.org/wiki/ATS_(wheels)
# ---
# Constructor ID: bar
# Constructor Name: BAR
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/British_American_Racing
# ---
# Constructor ID: behra-porsche
# Constructor Name: Behra-Porsche
# Nationality: Italian
# Constructor Information: http://en.wikipedia.org/wiki/Behra-Porsche
# ---
# Constructor ID: bellasi
# Constructor Name: Bellasi
# Nationality: Swiss
# Constructor Information: http://en.wikipedia.org/wiki/Bellasi
# ---
# Constructor ID: benetton
# Constructor Name: Benetton
# Nationality: Italian
# Constructor Information: http://en.wikipedia.org/wiki/Benetton_Formula
# ---
# Constructor ID: bmw
# Constructor Name: BMW
# Nationality: German
# Constructor Information: http://en.wikipedia.org/wiki/BMW
# ---
# Constructor ID: bmw_sauber
# Constructor Name: BMW Sauber
# Nationality: German
# Constructor Information: http://en.wikipedia.org/wiki/BMW_Sauber
# ---
# Constructor ID: boro
# Constructor Name: Boro
# Nationality: Dutch
# Constructor Information: http://en.wikipedia.org/wiki/Boro_(Formula_One)
# ---
# Constructor ID: brabham
# Constructor Name: Brabham
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Brabham
# ---
# Constructor ID: brabham-alfa_romeo
# Constructor Name: Brabham-Alfa Romeo
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Brabham
# ---
# Constructor ID: brabham-brm
# Constructor Name: Brabham-BRM
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Brabham
# ---
# Constructor ID: brabham-climax
# Constructor Name: Brabham-Climax
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Brabham
# ---
# Constructor ID: brabham-ford
# Constructor Name: Brabham-Ford
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Brabham
# ---
# Constructor ID: brabham-repco
# Constructor Name: Brabham-Repco
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Brabham
# ---
# Constructor ID: brawn
# Constructor Name: Brawn
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Brawn_GP
# ---
# Constructor ID: brm
# Constructor Name: BRM
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/BRM
# ---

# %%
url = "http://ergast.com/api/f1/2010/constructors"

# Make a GET request to the Ergast API
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the XML response
    root = ET.fromstring(response.content)

    # Define the namespace
    ns = {'mrd': 'http://ergast.com/mrd/1.5'}

    # Find all Circuit elements
    constructors_2010 = root.findall('.//mrd:Constructor', ns)
    
    # Check if circuits were found
    if constructors_2010:
        # Extract data for each circuit
        for constructor in constructors_2010:
            constructor_2010_id = constructor.attrib['constructorId']
            constructor_2010_name = constructor.find('mrd:Name', ns).text
            nationality_2010 = constructor.find('mrd:Nationality', ns).text
            constructor_2010_information = constructor.attrib['url']

            # Print each constructor's details
            print(f"Constructor ID: {constructor_2010_id}")
            print(f"Constructor Name: {constructor_2010_name}")
            print(f"Nationality: {nationality_2010}")
            print(f"Constructor Information: {constructor_2010_information}")
            print('---')
    else:
        print("No circuits found. Check the XML structure and namespace.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# Constructor ID: ferrari
# Constructor Name: Ferrari
# Nationality: Italian
# Constructor Information: http://en.wikipedia.org/wiki/Scuderia_Ferrari
# ---
# Constructor ID: force_india
# Constructor Name: Force India
# Nationality: Indian
# Constructor Information: http://en.wikipedia.org/wiki/Racing_Point_Force_India
# ---
# Constructor ID: hrt
# Constructor Name: HRT
# Nationality: Spanish
# Constructor Information: http://en.wikipedia.org/wiki/Hispania_Racing
# ---
# Constructor ID: lotus_racing
# Constructor Name: Lotus
# Nationality: Malaysian
# Constructor Information: http://en.wikipedia.org/wiki/Lotus_Racing
# ---
# Constructor ID: mclaren
# Constructor Name: McLaren
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/McLaren
# ---
# Constructor ID: mercedes
# Constructor Name: Mercedes
# Nationality: German
# Constructor Information: http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One
# ---
# Constructor ID: red_bull
# Constructor Name: Red Bull
# Nationality: Austrian
# Constructor Information: http://en.wikipedia.org/wiki/Red_Bull_Racing
# ---
# Constructor ID: renault
# Constructor Name: Renault
# Nationality: French
# Constructor Information: http://en.wikipedia.org/wiki/Renault_in_Formula_One
# ---
# Constructor ID: sauber
# Constructor Name: Sauber
# Nationality: Swiss
# Constructor Information: http://en.wikipedia.org/wiki/Sauber
# ---
# Constructor ID: toro_rosso
# Constructor Name: Toro Rosso
# Nationality: Italian
# Constructor Information: http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# ---
# Constructor ID: virgin
# Constructor Name: Virgin
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Virgin_Racing
# ---
# Constructor ID: williams
# Constructor Name: Williams
# Nationality: British
# Constructor Information: http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering
# ---

# %% [markdown]
# ## 4. [Driver Endpoint](#driver-endpoint)

# %%
url = "http://ergast.com/api/f1/drivers"

# %%
# Make a GET request to the Ergast API
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Print the beginning of the raw XML response
    print(response.text[:1000])  # Increase the number if needed# Check if the request was successful
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <?xml-stylesheet type="text/xsl" href="/schemas/mrd-1.5.xsl"?>
# <MRData xmlns="http://ergast.com/mrd/1.5" series="f1" url="http://ergast.com/api/f1/drivers" limit="30" offset="0" total="858">
# 	<DriverTable>
# 		<Driver driverId="abate" url="http://en.wikipedia.org/wiki/Carlo_Mario_Abate">
# 			<GivenName>Carlo</GivenName>
# 			<FamilyName>Abate</FamilyName>
# 			<DateOfBirth>1932-07-10</DateOfBirth>
# 			<Nationality>Italian</Nationality>
# 		</Driver>
# 		<Driver driverId="abecassis" url="http://en.wikipedia.org/wiki/George_Abecassis">
# 			<GivenName>George</GivenName>
# 			<FamilyName>Abecassis</FamilyName>
# 			<DateOfBirth>1913-03-21</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="acheson" url="http://en.wikipedia.org/wiki/Kenny_Acheson">
# 			<GivenName>Kenny</GivenName>
# 			<FamilyName>Acheson</FamilyName>
# 			<DateOfBirth>1957-11-27</DateOfBirth>
# 			<Nationality>British</Nationality>
# 		</Driver>
# 		<Driver driverId="adams" url="h

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the XML response
    root = ET.fromstring(response.content)
    # Define the namespace
    ns = {'mrd': 'http://ergast.com/mrd/1.5'}
    # Find all Driver elements
    drivers = root.findall('.//mrd:Driver', ns)
    # Check if drivers were found
    if drivers:
        # Extract data for each driver
        for driver in drivers:
            driver_id = driver.attrib['driverId']
            driver_name = driver.find('mrd:GivenName', ns).text
            driver_family_name = driver.find('mrd:FamilyName', ns).text
            nationality = driver.find('mrd:Nationality', ns).text
            d_o_b = driver.find('mrd:DateOfBirth', ns).text
            driver_information = driver.attrib['url']

            # Print each driver's details
            print(f"Driver ID: {driver_id}")
            print(f"Driver Name: {driver_name}")
            print(f"Driver Family Name: {driver_family_name}")
            print(f"Nationality: {nationality}")
            print(f"Date of Birth: {d_o_b}")
            print(f"Driver Information: {driver_information}")
            print('---')
    else:
        print("No circuits found. Check the XML structure and namespace.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# Driver ID: abate
# Driver Name: Carlo
# Driver Family Name: Abate
# Nationality: Italian
# Date of Birth: 1932-07-10
# Driver Information: http://en.wikipedia.org/wiki/Carlo_Mario_Abate
# ---
# Driver ID: abecassis
# Driver Name: George
# Driver Family Name: Abecassis
# Nationality: British
# Date of Birth: 1913-03-21
# Driver Information: http://en.wikipedia.org/wiki/George_Abecassis
# ---
# Driver ID: acheson
# Driver Name: Kenny
# Driver Family Name: Acheson
# Nationality: British
# Date of Birth: 1957-11-27
# Driver Information: http://en.wikipedia.org/wiki/Kenny_Acheson
# ---
# Driver ID: adams
# Driver Name: Philippe
# Driver Family Name: Adams
# Nationality: Belgian
# Date of Birth: 1969-11-19
# Driver Information: http://en.wikipedia.org/wiki/Philippe_Adams
# ---
# Driver ID: ader
# Driver Name: Walt
# Driver Family Name: Ader
# Nationality: American
# Date of Birth: 1913-12-15
# Driver Information: http://en.wikipedia.org/wiki/Walt_Ader
# ---
# Driver ID: adolff
# Driver Name: Kurt
# Driver Family Name: Adolff
# Nationality: German
# Date of Birth: 1921-11-05
# Driver Information: http://en.wikipedia.org/wiki/Kurt_Adolff
# ---
# Driver ID: agabashian
# Driver Name: Fred
# Driver Family Name: Agabashian
# Nationality: American
# Date of Birth: 1913-08-21
# Driver Information: http://en.wikipedia.org/wiki/Fred_Agabashian
# ---
# Driver ID: ahrens
# Driver Name: Kurt
# Driver Family Name: Ahrens
# Nationality: German
# Date of Birth: 1940-04-19
# Driver Information: http://en.wikipedia.org/wiki/Kurt_Ahrens,_Jr.
# ---
# Driver ID: aitken
# Driver Name: Jack
# Driver Family Name: Aitken
# Nationality: British
# Date of Birth: 1995-09-23
# Driver Information: http://en.wikipedia.org/wiki/Jack_Aitken
# ---
# Driver ID: albers
# Driver Name: Christijan
# Driver Family Name: Albers
# Nationality: Dutch
# Date of Birth: 1979-04-16
# Driver Information: http://en.wikipedia.org/wiki/Christijan_Albers
# ---
# Driver ID: albon
# Driver Name: Alexander
# Driver Family Name: Albon
# Nationality: Thai
# Date of Birth: 1996-03-23
# Driver Information: http://en.wikipedia.org/wiki/Alexander_Albon
# ---
# Driver ID: alboreto
# Driver Name: Michele
# Driver Family Name: Alboreto
# Nationality: Italian
# Date of Birth: 1956-12-23
# Driver Information: http://en.wikipedia.org/wiki/Michele_Alboreto
# ---
# Driver ID: alesi
# Driver Name: Jean
# Driver Family Name: Alesi
# Nationality: French
# Date of Birth: 1964-06-11
# Driver Information: http://en.wikipedia.org/wiki/Jean_Alesi
# ---
# Driver ID: alguersuari
# Driver Name: Jaime
# Driver Family Name: Alguersuari
# Nationality: Spanish
# Date of Birth: 1990-03-23
# Driver Information: http://en.wikipedia.org/wiki/Jaime_Alguersuari
# ---
# Driver ID: alliot
# Driver Name: Philippe
# Driver Family Name: Alliot
# Nationality: French
# Date of Birth: 1954-07-27
# Driver Information: http://en.wikipedia.org/wiki/Philippe_Alliot
# ---
# Driver ID: allison
# Driver Name: Cliff
# Driver Family Name: Allison
# Nationality: British
# Date of Birth: 1932-02-08
# Driver Information: http://en.wikipedia.org/wiki/Cliff_Allison
# ---
# Driver ID: alonso
# Driver Name: Fernando
# Driver Family Name: Alonso
# Nationality: Spanish
# Date of Birth: 1981-07-29
# Driver Information: http://en.wikipedia.org/wiki/Fernando_Alonso
# ---
# Driver ID: amati
# Driver Name: Giovanna
# Driver Family Name: Amati
# Nationality: Italian
# Date of Birth: 1959-07-20
# Driver Information: http://en.wikipedia.org/wiki/Giovanna_Amati
# ---
# Driver ID: amick
# Driver Name: Red
# Driver Family Name: Amick
# Nationality: American
# Date of Birth: 1929-01-19
# Driver Information: http://en.wikipedia.org/wiki/Red_Amick
# ---
# Driver ID: george_amick
# Driver Name: George
# Driver Family Name: Amick
# Nationality: American
# Date of Birth: 1924-10-24
# Driver Information: http://en.wikipedia.org/wiki/George_Amick
# ---
# Driver ID: amon
# Driver Name: Chris
# Driver Family Name: Amon
# Nationality: New Zealander
# Date of Birth: 1943-07-20
# Driver Information: http://en.wikipedia.org/wiki/Chris_Amon
# ---
# Driver ID: anderson
# Driver Name: Bob
# Driver Family Name: Anderson
# Nationality: British
# Date of Birth: 1931-05-19
# Driver Information: http://en.wikipedia.org/wiki/Bob_Anderson_(racing_driver)
# ---
# Driver ID: andersson
# Driver Name: Conny
# Driver Family Name: Andersson
# Nationality: Swedish
# Date of Birth: 1939-12-28
# Driver Information: http://en.wikipedia.org/wiki/Conny_Andersson_(racing_driver)
# ---
# Driver ID: andretti
# Driver Name: Michael
# Driver Family Name: Andretti
# Nationality: American
# Date of Birth: 1962-10-05
# Driver Information: http://en.wikipedia.org/wiki/Michael_Andretti
# ---
# Driver ID: mario_andretti
# Driver Name: Mario
# Driver Family Name: Andretti
# Nationality: American
# Date of Birth: 1940-02-28
# Driver Information: http://en.wikipedia.org/wiki/Mario_Andretti
# ---
# Driver ID: andrews
# Driver Name: Keith
# Driver Family Name: Andrews
# Nationality: American
# Date of Birth: 1920-06-15
# Driver Information: http://en.wikipedia.org/wiki/Keith_Andrews_(driver)
# ---
# Driver ID: apicella
# Driver Name: Marco
# Driver Family Name: Apicella
# Nationality: Italian
# Date of Birth: 1965-10-07
# Driver Information: http://en.wikipedia.org/wiki/Marco_Apicella
# ---
# Driver ID: armi
# Driver Name: Frank
# Driver Family Name: Armi
# Nationality: American
# Date of Birth: 1918-10-12
# Driver Information: http://en.wikipedia.org/wiki/Frank_Armi
# ---
# Driver ID: arnold
# Driver Name: Chuck
# Driver Family Name: Arnold
# Nationality: American
# Date of Birth: 1926-05-30
# Driver Information: http://en.wikipedia.org/wiki/Chuck_Arnold
# ---
# Driver ID: arnoux
# Driver Name: René
# Driver Family Name: Arnoux
# Nationality: French
# Date of Birth: 1948-07-04
# Driver Information: http://en.wikipedia.org/wiki/Ren%C3%A9_Arnoux
# ---

# %%
url = "http://ergast.com/api/f1/2010/drivers"
# Make a GET request to the Ergast API
response = requests.get(url)
# Check if the request was successful
if response.status_code == 200:
    # Parse the XML response
    root = ET.fromstring(response.content)
    # Define the namespace
    ns = {'mrd': 'http://ergast.com/mrd/1.5'}
    # Find all Circuit elements
    drivers_2010 = root.findall('.//mrd:Driver', ns)
    # Check if circuits were found
    if drivers_2010:
        # Extract data for each circuit
        for driver in drivers_2010:
            driver_id = driver.attrib['driverId']
            driver_name = driver.find('mrd:GivenName', ns).text
            driver_family_name = driver.find('mrd:FamilyName', ns).text
            nationality = driver.find('mrd:Nationality', ns).text
            d_o_b = driver.find('mrd:DateOfBirth', ns).text
            driver_information = driver.attrib['url']

            # Print each constructor's details
            print(f"Driver ID: {driver_id}")
            print(f"Driver Name: {driver_name}")
            print(f"Driver Family Name: {driver_family_name}")
            print(f"Nationality: {nationality}")
            print(f"Date of Birth: {d_o_b}")
            print(f"Driver Information: {driver_information}")
            print('---')
    else:
        print("No circuits found. Check the XML structure and namespace.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# Driver ID: alguersuari
# Driver Name: Jaime
# Driver Family Name: Alguersuari
# Nationality: Spanish
# Date of Birth: 1990-03-23
# Driver Information: http://en.wikipedia.org/wiki/Jaime_Alguersuari
# ---
# Driver ID: alonso
# Driver Name: Fernando
# Driver Family Name: Alonso
# Nationality: Spanish
# Date of Birth: 1981-07-29
# Driver Information: http://en.wikipedia.org/wiki/Fernando_Alonso
# ---
# Driver ID: barrichello
# Driver Name: Rubens
# Driver Family Name: Barrichello
# Nationality: Brazilian
# Date of Birth: 1972-05-23
# Driver Information: http://en.wikipedia.org/wiki/Rubens_Barrichello
# ---
# Driver ID: buemi
# Driver Name: Sébastien
# Driver Family Name: Buemi
# Nationality: Swiss
# Date of Birth: 1988-10-31
# Driver Information: http://en.wikipedia.org/wiki/S%C3%A9bastien_Buemi
# ---
# Driver ID: button
# Driver Name: Jenson
# Driver Family Name: Button
# Nationality: British
# Date of Birth: 1980-01-19
# Driver Information: http://en.wikipedia.org/wiki/Jenson_Button
# ---
# Driver ID: chandhok
# Driver Name: Karun
# Driver Family Name: Chandhok
# Nationality: Indian
# Date of Birth: 1984-01-19
# Driver Information: http://en.wikipedia.org/wiki/Karun_Chandhok
# ---
# Driver ID: rosa
# Driver Name: Pedro
# Driver Family Name: de la Rosa
# Nationality: Spanish
# Date of Birth: 1971-02-24
# Driver Information: http://en.wikipedia.org/wiki/Pedro_de_la_Rosa
# ---
# Driver ID: grassi
# Driver Name: Lucas
# Driver Family Name: di Grassi
# Nationality: Brazilian
# Date of Birth: 1984-08-11
# Driver Information: http://en.wikipedia.org/wiki/Lucas_di_Grassi
# ---
# Driver ID: glock
# Driver Name: Timo
# Driver Family Name: Glock
# Nationality: German
# Date of Birth: 1982-03-18
# Driver Information: http://en.wikipedia.org/wiki/Timo_Glock
# ---
# Driver ID: hamilton
# Driver Name: Lewis
# Driver Family Name: Hamilton
# Nationality: British
# Date of Birth: 1985-01-07
# Driver Information: http://en.wikipedia.org/wiki/Lewis_Hamilton
# ---
# Driver ID: heidfeld
# Driver Name: Nick
# Driver Family Name: Heidfeld
# Nationality: German
# Date of Birth: 1977-05-10
# Driver Information: http://en.wikipedia.org/wiki/Nick_Heidfeld
# ---
# Driver ID: hulkenberg
# Driver Name: Nico
# Driver Family Name: Hülkenberg
# Nationality: German
# Date of Birth: 1987-08-19
# Driver Information: http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg
# ---
# Driver ID: klien
# Driver Name: Christian
# Driver Family Name: Klien
# Nationality: Austrian
# Date of Birth: 1983-02-07
# Driver Information: http://en.wikipedia.org/wiki/Christian_Klien
# ---
# Driver ID: kobayashi
# Driver Name: Kamui
# Driver Family Name: Kobayashi
# Nationality: Japanese
# Date of Birth: 1986-09-13
# Driver Information: http://en.wikipedia.org/wiki/Kamui_Kobayashi
# ---
# Driver ID: kovalainen
# Driver Name: Heikki
# Driver Family Name: Kovalainen
# Nationality: Finnish
# Date of Birth: 1981-10-19
# Driver Information: http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ---
# Driver ID: kubica
# Driver Name: Robert
# Driver Family Name: Kubica
# Nationality: Polish
# Date of Birth: 1984-12-07
# Driver Information: http://en.wikipedia.org/wiki/Robert_Kubica
# ---
# Driver ID: liuzzi
# Driver Name: Vitantonio
# Driver Family Name: Liuzzi
# Nationality: Italian
# Date of Birth: 1980-08-06
# Driver Information: http://en.wikipedia.org/wiki/Vitantonio_Liuzzi
# ---
# Driver ID: massa
# Driver Name: Felipe
# Driver Family Name: Massa
# Nationality: Brazilian
# Date of Birth: 1981-04-25
# Driver Information: http://en.wikipedia.org/wiki/Felipe_Massa
# ---
# Driver ID: petrov
# Driver Name: Vitaly
# Driver Family Name: Petrov
# Nationality: Russian
# Date of Birth: 1984-09-08
# Driver Information: http://en.wikipedia.org/wiki/Vitaly_Petrov
# ---
# Driver ID: rosberg
# Driver Name: Nico
# Driver Family Name: Rosberg
# Nationality: German
# Date of Birth: 1985-06-27
# Driver Information: http://en.wikipedia.org/wiki/Nico_Rosberg
# ---
# Driver ID: michael_schumacher
# Driver Name: Michael
# Driver Family Name: Schumacher
# Nationality: German
# Date of Birth: 1969-01-03
# Driver Information: http://en.wikipedia.org/wiki/Michael_Schumacher
# ---
# Driver ID: bruno_senna
# Driver Name: Bruno
# Driver Family Name: Senna
# Nationality: Brazilian
# Date of Birth: 1983-10-15
# Driver Information: http://en.wikipedia.org/wiki/Bruno_Senna
# ---
# Driver ID: sutil
# Driver Name: Adrian
# Driver Family Name: Sutil
# Nationality: German
# Date of Birth: 1983-01-11
# Driver Information: http://en.wikipedia.org/wiki/Adrian_Sutil
# ---
# Driver ID: trulli
# Driver Name: Jarno
# Driver Family Name: Trulli
# Nationality: Italian
# Date of Birth: 1974-07-13
# Driver Information: http://en.wikipedia.org/wiki/Jarno_Trulli
# ---
# Driver ID: vettel
# Driver Name: Sebastian
# Driver Family Name: Vettel
# Nationality: German
# Date of Birth: 1987-07-03
# Driver Information: http://en.wikipedia.org/wiki/Sebastian_Vettel
# ---
# Driver ID: webber
# Driver Name: Mark
# Driver Family Name: Webber
# Nationality: Australian
# Date of Birth: 1976-08-27
# Driver Information: http://en.wikipedia.org/wiki/Mark_Webber_(racing_driver)
# ---
# Driver ID: yamamoto
# Driver Name: Sakon
# Driver Family Name: Yamamoto
# Nationality: Japanese
# Date of Birth: 1982-07-09
# Driver Information: http://en.wikipedia.org/wiki/Sakon_Yamamoto
# ---

# %%
url = "http://ergast.com/api/f1/2023/drivers"
# Make a GET request to the Ergast API
response = requests.get(url)
# Check if the request was successful
if response.status_code == 200:
    # Parse the XML response
    root = ET.fromstring(response.content)
    # Define the namespace
    ns = {'mrd': 'http://ergast.com/mrd/1.5'}
    # Find all Circuit elements
    drivers_2023 = root.findall('.//mrd:Driver', ns)
    # Check if circuits were found
    if drivers_2023:
        # Extract data for each circuit
        for driver in drivers_2023:
            driver_id = driver.attrib['driverId']
            driver_name = driver.find('mrd:GivenName', ns).text
            driver_family_name = driver.find('mrd:FamilyName', ns).text
            nationality = driver.find('mrd:Nationality', ns).text
            d_o_b = driver.find('mrd:DateOfBirth', ns).text
            driver_information = driver.attrib['url']

            # Print each constructor's details
            print(f"Driver ID: {driver_id}")
            print(f"Driver Name: {driver_name}")
            print(f"Driver Family Name: {driver_family_name}")
            print(f"Nationality: {nationality}")
            print(f"Date of Birth: {d_o_b}")
            print(f"Driver Information: {driver_information}")
            print('---')
    else:
        print("No circuits found. Check the XML structure and namespace.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# Driver ID: albon
# Driver Name: Alexander
# Driver Family Name: Albon
# Nationality: Thai
# Date of Birth: 1996-03-23
# Driver Information: http://en.wikipedia.org/wiki/Alexander_Albon
# ---
# Driver ID: alonso
# Driver Name: Fernando
# Driver Family Name: Alonso
# Nationality: Spanish
# Date of Birth: 1981-07-29
# Driver Information: http://en.wikipedia.org/wiki/Fernando_Alonso
# ---
# Driver ID: bottas
# Driver Name: Valtteri
# Driver Family Name: Bottas
# Nationality: Finnish
# Date of Birth: 1989-08-28
# Driver Information: http://en.wikipedia.org/wiki/Valtteri_Bottas
# ---
# Driver ID: de_vries
# Driver Name: Nyck
# Driver Family Name: de Vries
# Nationality: Dutch
# Date of Birth: 1995-02-06
# Driver Information: http://en.wikipedia.org/wiki/Nyck_de_Vries
# ---
# Driver ID: gasly
# Driver Name: Pierre
# Driver Family Name: Gasly
# Nationality: French
# Date of Birth: 1996-02-07
# Driver Information: http://en.wikipedia.org/wiki/Pierre_Gasly
# ---
# Driver ID: hamilton
# Driver Name: Lewis
# Driver Family Name: Hamilton
# Nationality: British
# Date of Birth: 1985-01-07
# Driver Information: http://en.wikipedia.org/wiki/Lewis_Hamilton
# ---
# Driver ID: hulkenberg
# Driver Name: Nico
# Driver Family Name: Hülkenberg
# Nationality: German
# Date of Birth: 1987-08-19
# Driver Information: http://en.wikipedia.org/wiki/Nico_H%C3%BClkenberg
# ---
# Driver ID: lawson
# Driver Name: Liam
# Driver Family Name: Lawson
# Nationality: New Zealander
# Date of Birth: 2002-02-11
# Driver Information: http://en.wikipedia.org/wiki/Liam_Lawson
# ---
# Driver ID: leclerc
# Driver Name: Charles
# Driver Family Name: Leclerc
# Nationality: Monegasque
# Date of Birth: 1997-10-16
# Driver Information: http://en.wikipedia.org/wiki/Charles_Leclerc
# ---
# Driver ID: kevin_magnussen
# Driver Name: Kevin
# Driver Family Name: Magnussen
# Nationality: Danish
# Date of Birth: 1992-10-05
# Driver Information: http://en.wikipedia.org/wiki/Kevin_Magnussen
# ---
# Driver ID: norris
# Driver Name: Lando
# Driver Family Name: Norris
# Nationality: British
# Date of Birth: 1999-11-13
# Driver Information: http://en.wikipedia.org/wiki/Lando_Norris
# ---
# Driver ID: ocon
# Driver Name: Esteban
# Driver Family Name: Ocon
# Nationality: French
# Date of Birth: 1996-09-17
# Driver Information: http://en.wikipedia.org/wiki/Esteban_Ocon
# ---
# Driver ID: perez
# Driver Name: Sergio
# Driver Family Name: Pérez
# Nationality: Mexican
# Date of Birth: 1990-01-26
# Driver Information: http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez
# ---
# Driver ID: piastri
# Driver Name: Oscar
# Driver Family Name: Piastri
# Nationality: Australian
# Date of Birth: 2001-04-06
# Driver Information: http://en.wikipedia.org/wiki/Oscar_Piastri
# ---
# Driver ID: ricciardo
# Driver Name: Daniel
# Driver Family Name: Ricciardo
# Nationality: Australian
# Date of Birth: 1989-07-01
# Driver Information: http://en.wikipedia.org/wiki/Daniel_Ricciardo
# ---
# Driver ID: russell
# Driver Name: George
# Driver Family Name: Russell
# Nationality: British
# Date of Birth: 1998-02-15
# Driver Information: http://en.wikipedia.org/wiki/George_Russell_(racing_driver)
# ---
# Driver ID: sainz
# Driver Name: Carlos
# Driver Family Name: Sainz
# Nationality: Spanish
# Date of Birth: 1994-09-01
# Driver Information: http://en.wikipedia.org/wiki/Carlos_Sainz_Jr.
# ---
# Driver ID: sargeant
# Driver Name: Logan
# Driver Family Name: Sargeant
# Nationality: American
# Date of Birth: 2000-12-31
# Driver Information: http://en.wikipedia.org/wiki/Logan_Sargeant
# ---
# Driver ID: stroll
# Driver Name: Lance
# Driver Family Name: Stroll
# Nationality: Canadian
# Date of Birth: 1998-10-29
# Driver Information: http://en.wikipedia.org/wiki/Lance_Stroll
# ---
# Driver ID: tsunoda
# Driver Name: Yuki
# Driver Family Name: Tsunoda
# Nationality: Japanese
# Date of Birth: 2000-05-11
# Driver Information: http://en.wikipedia.org/wiki/Yuki_Tsunoda
# ---
# Driver ID: max_verstappen
# Driver Name: Max
# Driver Family Name: Verstappen
# Nationality: Dutch
# Date of Birth: 1997-09-30
# Driver Information: http://en.wikipedia.org/wiki/Max_Verstappen
# ---
# Driver ID: zhou
# Driver Name: Guanyu
# Driver Family Name: Zhou
# Nationality: Chinese
# Date of Birth: 1999-05-30
# Driver Information: http://en.wikipedia.org/wiki/Zhou_Guanyu
# ---

# %% [markdown]
# ## 5. [Seasons Endpoint](#seasons-endpoint)

# %%
url = "http://ergast.com/api/f1/seasons"
# Make a GET request to the Ergast API
response = requests.get(url)
# Check if the request was successful
if response.status_code == 200:
    # Print the beginning of the raw XML response
    print(response.text[:1000])  # Increase the number if needed# Check if the request was successful
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <?xml-stylesheet type="text/xsl" href="/schemas/mrd-1.5.xsl"?>
# <MRData xmlns="http://ergast.com/mrd/1.5" series="f1" url="http://ergast.com/api/f1/seasons" limit="30" offset="0" total="75">
# 	<SeasonTable>
# 		<Season url="http://en.wikipedia.org/wiki/1950_Formula_One_season">1950</Season>
# 		<Season url="http://en.wikipedia.org/wiki/1951_Formula_One_season">1951</Season>
# 		<Season url="http://en.wikipedia.org/wiki/1952_Formula_One_season">1952</Season>
# 		<Season url="http://en.wikipedia.org/wiki/1953_Formula_One_season">1953</Season>
# 		<Season url="http://en.wikipedia.org/wiki/1954_Formula_One_season">1954</Season>
# 		<Season url="http://en.wikipedia.org/wiki/1955_Formula_One_season">1955</Season>
# 		<Season url="http://en.wikipedia.org/wiki/1956_Formula_One_season">1956</Season>
# 		<Season url="http://en.wikipedia.org/wiki/1957_Formula_One_season">1957</Season>
# 		<Season url="http://en.wikipedia.org/wiki/1958_Formula_One_season">1958</Season>
# 		<Season

# %%
url = "http://ergast.com/api/f1/seasons"
# Make a GET request to the Ergast API
response = requests.get(url)
# Check if the request was successful
if response.status_code == 200:
    # Parse the XML response
    root = ET.fromstring(response.content)
    # Define the namespace
    ns = {'mrd': 'http://ergast.com/mrd/1.5'}
    # Find all season elements
    seasons = root.findall('.//mrd:Season', ns)
    # Check if seasons were found
    if seasons:
        # Extract data for each season
        for season in seasons:
            season_information = season.attrib['url']
            season_year = season.text
            
            print(f"Season Information: {season_information}")
            print(f"Year: {season_year}")
            print("---")
    else:
        print("No seasons found. Check the XML structure and namespace.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# Season Information: http://en.wikipedia.org/wiki/1950_Formula_One_season
# Year: 1950
# ---
# Season Information: http://en.wikipedia.org/wiki/1951_Formula_One_season
# Year: 1951
# ---
# Season Information: http://en.wikipedia.org/wiki/1952_Formula_One_season
# Year: 1952
# ---
# Season Information: http://en.wikipedia.org/wiki/1953_Formula_One_season
# Year: 1953
# ---
# Season Information: http://en.wikipedia.org/wiki/1954_Formula_One_season
# Year: 1954
# ---
# Season Information: http://en.wikipedia.org/wiki/1955_Formula_One_season
# Year: 1955
# ---
# Season Information: http://en.wikipedia.org/wiki/1956_Formula_One_season
# Year: 1956
# ---
# Season Information: http://en.wikipedia.org/wiki/1957_Formula_One_season
# Year: 1957
# ---
# Season Information: http://en.wikipedia.org/wiki/1958_Formula_One_season
# Year: 1958
# ---
# Season Information: http://en.wikipedia.org/wiki/1959_Formula_One_season
# Year: 1959
# ---
# Season Information: http://en.wikipedia.org/wiki/1960_Formula_One_season
# Year: 1960
# ---
# Season Information: http://en.wikipedia.org/wiki/1961_Formula_One_season
# Year: 1961
# ---
# Season Information: http://en.wikipedia.org/wiki/1962_Formula_One_season
# Year: 1962
# ---
# Season Information: http://en.wikipedia.org/wiki/1963_Formula_One_season
# Year: 1963
# ---
# Season Information: http://en.wikipedia.org/wiki/1964_Formula_One_season
# Year: 1964
# ---
# Season Information: http://en.wikipedia.org/wiki/1965_Formula_One_season
# Year: 1965
# ---
# Season Information: http://en.wikipedia.org/wiki/1966_Formula_One_season
# Year: 1966
# ---
# Season Information: http://en.wikipedia.org/wiki/1967_Formula_One_season
# Year: 1967
# ---
# Season Information: http://en.wikipedia.org/wiki/1968_Formula_One_season
# Year: 1968
# ---
# Season Information: http://en.wikipedia.org/wiki/1969_Formula_One_season
# Year: 1969
# ---
# Season Information: http://en.wikipedia.org/wiki/1970_Formula_One_season
# Year: 1970
# ---
# Season Information: http://en.wikipedia.org/wiki/1971_Formula_One_season
# Year: 1971
# ---
# Season Information: http://en.wikipedia.org/wiki/1972_Formula_One_season
# Year: 1972
# ---
# Season Information: http://en.wikipedia.org/wiki/1973_Formula_One_season
# Year: 1973
# ---
# Season Information: http://en.wikipedia.org/wiki/1974_Formula_One_season
# Year: 1974
# ---
# Season Information: http://en.wikipedia.org/wiki/1975_Formula_One_season
# Year: 1975
# ---
# Season Information: http://en.wikipedia.org/wiki/1976_Formula_One_season
# Year: 1976
# ---
# Season Information: http://en.wikipedia.org/wiki/1977_Formula_One_season
# Year: 1977
# ---
# Season Information: http://en.wikipedia.org/wiki/1978_Formula_One_season
# Year: 1978
# ---
# Season Information: http://en.wikipedia.org/wiki/1979_Formula_One_season
# Year: 1979
# ---

# %%
base_url = "http://ergast.com/api/f1/seasons"

# Initialize variables
all_seasons = []
current_offset = 0
total_seasons = None

while total_seasons is None or current_offset < total_seasons:
    # Construct the URL with the current offset
    url = f"{base_url}?offset={current_offset}"
    
    # Make the GET request
    response = requests.get(url)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the XML response
        root = ET.fromstring(response.content)
        
        # Define the namespace
        ns = {'mrd': 'http://ergast.com/mrd/1.5'}
        
        # Find all Season elements
        seasons = root.findall('.//mrd:Season', ns)
        
        # Check if seasons were found
        if seasons:
            # Extract data for each season
            for season in seasons:
                season_information = season.attrib['url']
                season_year = season.text
                all_seasons.append((season_year, season_information))
        else:
            print("No more seasons found.")
            break
        
        # Read total, limit, and offset from the MRData element
        mr_data = root.find('.//mrd:MRData', ns)
        total_seasons = int(root.attrib['total'])
        limit = int(root.attrib['limit'])
        current_offset += limit
    else:
        print(f"Failed to retrieve data: {response.status_code}")
        break

# Print all seasons
for year, info in all_seasons:
    print(f"Year: {year}, Info: {info}")
# Out:
# Year: 1950, Info: http://en.wikipedia.org/wiki/1950_Formula_One_season
# Year: 1951, Info: http://en.wikipedia.org/wiki/1951_Formula_One_season
# Year: 1952, Info: http://en.wikipedia.org/wiki/1952_Formula_One_season
# Year: 1953, Info: http://en.wikipedia.org/wiki/1953_Formula_One_season
# Year: 1954, Info: http://en.wikipedia.org/wiki/1954_Formula_One_season
# Year: 1955, Info: http://en.wikipedia.org/wiki/1955_Formula_One_season
# Year: 1956, Info: http://en.wikipedia.org/wiki/1956_Formula_One_season
# Year: 1957, Info: http://en.wikipedia.org/wiki/1957_Formula_One_season
# Year: 1958, Info: http://en.wikipedia.org/wiki/1958_Formula_One_season
# Year: 1959, Info: http://en.wikipedia.org/wiki/1959_Formula_One_season
# Year: 1960, Info: http://en.wikipedia.org/wiki/1960_Formula_One_season
# Year: 1961, Info: http://en.wikipedia.org/wiki/1961_Formula_One_season
# Year: 1962, Info: http://en.wikipedia.org/wiki/1962_Formula_One_season
# Year: 1963, Info: http://en.wikipedia.org/wiki/1963_Formula_One_season
# Year: 1964, Info: http://en.wikipedia.org/wiki/1964_Formula_One_season
# Year: 1965, Info: http://en.wikipedia.org/wiki/1965_Formula_One_season
# Year: 1966, Info: http://en.wikipedia.org/wiki/1966_Formula_One_season
# Year: 1967, Info: http://en.wikipedia.org/wiki/1967_Formula_One_season
# Year: 1968, Info: http://en.wikipedia.org/wiki/1968_Formula_One_season
# Year: 1969, Info: http://en.wikipedia.org/wiki/1969_Formula_One_season
# Year: 1970, Info: http://en.wikipedia.org/wiki/1970_Formula_One_season
# Year: 1971, Info: http://en.wikipedia.org/wiki/1971_Formula_One_season
# Year: 1972, Info: http://en.wikipedia.org/wiki/1972_Formula_One_season
# Year: 1973, Info: http://en.wikipedia.org/wiki/1973_Formula_One_season
# Year: 1974, Info: http://en.wikipedia.org/wiki/1974_Formula_One_season
# Year: 1975, Info: http://en.wikipedia.org/wiki/1975_Formula_One_season
# Year: 1976, Info: http://en.wikipedia.org/wiki/1976_Formula_One_season
# Year: 1977, Info: http://en.wikipedia.org/wiki/1977_Formula_One_season
# Year: 1978, Info: http://en.wikipedia.org/wiki/1978_Formula_One_season
# Year: 1979, Info: http://en.wikipedia.org/wiki/1979_Formula_One_season
# Year: 1980, Info: http://en.wikipedia.org/wiki/1980_Formula_One_season
# Year: 1981, Info: http://en.wikipedia.org/wiki/1981_Formula_One_season
# Year: 1982, Info: http://en.wikipedia.org/wiki/1982_Formula_One_season
# Year: 1983, Info: http://en.wikipedia.org/wiki/1983_Formula_One_season
# Year: 1984, Info: http://en.wikipedia.org/wiki/1984_Formula_One_season
# Year: 1985, Info: http://en.wikipedia.org/wiki/1985_Formula_One_season
# Year: 1986, Info: http://en.wikipedia.org/wiki/1986_Formula_One_season
# Year: 1987, Info: http://en.wikipedia.org/wiki/1987_Formula_One_season
# Year: 1988, Info: http://en.wikipedia.org/wiki/1988_Formula_One_season
# Year: 1989, Info: http://en.wikipedia.org/wiki/1989_Formula_One_season
# Year: 1990, Info: http://en.wikipedia.org/wiki/1990_Formula_One_season
# Year: 1991, Info: http://en.wikipedia.org/wiki/1991_Formula_One_season
# Year: 1992, Info: http://en.wikipedia.org/wiki/1992_Formula_One_season
# Year: 1993, Info: http://en.wikipedia.org/wiki/1993_Formula_One_season
# Year: 1994, Info: http://en.wikipedia.org/wiki/1994_Formula_One_season
# Year: 1995, Info: http://en.wikipedia.org/wiki/1995_Formula_One_season
# Year: 1996, Info: http://en.wikipedia.org/wiki/1996_Formula_One_season
# Year: 1997, Info: http://en.wikipedia.org/wiki/1997_Formula_One_season
# Year: 1998, Info: http://en.wikipedia.org/wiki/1998_Formula_One_season
# Year: 1999, Info: http://en.wikipedia.org/wiki/1999_Formula_One_season
# Year: 2000, Info: http://en.wikipedia.org/wiki/2000_Formula_One_season
# Year: 2001, Info: http://en.wikipedia.org/wiki/2001_Formula_One_season
# Year: 2002, Info: http://en.wikipedia.org/wiki/2002_Formula_One_season
# Year: 2003, Info: http://en.wikipedia.org/wiki/2003_Formula_One_season
# Year: 2004, Info: http://en.wikipedia.org/wiki/2004_Formula_One_season
# Year: 2005, Info: http://en.wikipedia.org/wiki/2005_Formula_One_season
# Year: 2006, Info: http://en.wikipedia.org/wiki/2006_Formula_One_season
# Year: 2007, Info: http://en.wikipedia.org/wiki/2007_Formula_One_season
# Year: 2008, Info: http://en.wikipedia.org/wiki/2008_Formula_One_season
# Year: 2009, Info: http://en.wikipedia.org/wiki/2009_Formula_One_season
# Year: 2010, Info: http://en.wikipedia.org/wiki/2010_Formula_One_season
# Year: 2011, Info: http://en.wikipedia.org/wiki/2011_Formula_One_season
# Year: 2012, Info: http://en.wikipedia.org/wiki/2012_Formula_One_season
# Year: 2013, Info: http://en.wikipedia.org/wiki/2013_Formula_One_season
# Year: 2014, Info: http://en.wikipedia.org/wiki/2014_Formula_One_season
# Year: 2015, Info: http://en.wikipedia.org/wiki/2015_Formula_One_season
# Year: 2016, Info: http://en.wikipedia.org/wiki/2016_Formula_One_season
# Year: 2017, Info: http://en.wikipedia.org/wiki/2017_Formula_One_season
# Year: 2018, Info: http://en.wikipedia.org/wiki/2018_Formula_One_World_Championship
# Year: 2019, Info: http://en.wikipedia.org/wiki/2019_Formula_One_World_Championship
# Year: 2020, Info: http://en.wikipedia.org/wiki/2020_Formula_One_World_Championship
# Year: 2021, Info: http://en.wikipedia.org/wiki/2021_Formula_One_World_Championship
# Year: 2022, Info: http://en.wikipedia.org/wiki/2022_Formula_One_World_Championship
# Year: 2023, Info: http://en.wikipedia.org/wiki/2023_Formula_One_World_Championship
# Year: 2024, Info: https://en.wikipedia.org/wiki/2024_Formula_One_World_Championship

# %% [markdown]
# ## Race Schedule Endpoint

# %%
url = "http://ergast.com/api/f1/2024"
response = requests.get(url)

if response.status_code==200:
    print(response.text[:1000])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <?xml-stylesheet type="text/xsl" href="/schemas/mrd-1.5.xsl"?>
# <MRData xmlns="http://ergast.com/mrd/1.5" series="f1" url="http://ergast.com/api/f1/2024" limit="30" offset="0" total="24">
# 	<RaceTable season="2024">
# 		<Race season="2024" round="1" url="https://en.wikipedia.org/wiki/2024_Bahrain_Grand_Prix">
# 			<RaceName>Bahrain Grand Prix</RaceName>
# 			<Circuit circuitId="bahrain" url="http://en.wikipedia.org/wiki/Bahrain_International_Circuit">
# 				<CircuitName>Bahrain International Circuit</CircuitName>
# 				<Location lat="26.0325" long="50.5106">
# 					<Locality>Sakhir</Locality>
# 					<Country>Bahrain</Country>
# 				</Location>
# 			</Circuit>
# 			<Date>2024-03-02</Date>
# 		</Race>
# 		<Race season="2024" round="2" url="https://en.wikipedia.org/wiki/2024_Saudi_Arabian_Grand_Prix">
# 			<RaceName>Saudi Arabian Grand Prix</RaceName>
# 			<Circuit circuitId="jeddah" url="http://en.wikipedia.org/wiki/Jeddah_Street_Circuit">
# 				<CircuitName>Jeddah Corniche Circui

# %%
url = "http://ergast.com/api/f1/2024"
# Make a GET request to the Ergast API
response = requests.get(url)
# Check if the request was successful
if response.status_code == 200:
    # Parse the XML response
    root = ET.fromstring(response.content)
    # Define the namespace
    ns = {'mrd': 'http://ergast.com/mrd/1.5'}
    # Find all seasons elements
    season_2024 = root.findall('.//mrd:Race', ns)
    # Check if seasons were found
    if season_2024:
        # Extract data for each race
        for race in season_2024:
            race_round = race.attrib.get('round')
            season_year = race.attrib['season']
            circuit = race.find('mrd:RaceName', ns).text
            circuit_name = circuit.find('mrd:CircuitName', ns).text
            location = circuit.find('mrd:Location', ns)
            locality = location.find('mrd:Locality', ns).text
            latitude = location.attrib['lat']
            longitude = location.attrib['long']
            country = circuit.find('mrd:Location/mrd:Country', ns).text
            race_information = race.attrib['url']
            
            
            print(f"Race Round: {race_round}")
            print(f"Year: {season_year}")
            print(f"Circuit: {circuit}")
            #print(f"Circuit Name: {circuit_name}")
            print(f"Locality: {locality}")
            print(f"Country: {country}")
            print(f"Latitude: {latitude}")
            print(f"Longitude: {longitude}")
            print(f"Race Information: {race_information}")
            print("---")
    else:
        print("No seasons found. Check the XML structure and namespace.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 19
#      17 season_year = race.attrib['season']
#      18 circuit = race.find('mrd:RaceName', ns).text
# ---> 19 circuit_name = circuit.find('mrd:CircuitName', ns).text
#      20 location = circuit.find('mrd:Location', ns)
#      21 locality = location.find('mrd:Locality', ns).text
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
url = "http://ergast.com/api/f1/2024"
# Make a GET request to the Ergast API
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
# Parse the XML response
root = ET.fromstring(response.content)
# Define the namespace
ns = {'mrd': 'http://ergast.com/mrd/1.5'}
print(f"ns: {ns}")
season_2024 = root.findall('.//mrd:Race', ns)
print(f"Season_2024: {season_2024}")
# Out:
# ns: {'mrd': 'http://ergast.com/mrd/1.5'}
# Season_2024: [<Element '{http://ergast.com/mrd/1.5}Race' at 0x11d79d0e0>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d7bd9f0>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d7bd310>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d7bdb80>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d7c7c70>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d7c7400>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d7c7680>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d82bdb0>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d894180>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d894540>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d894950>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d894d60>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d8ae0e0>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d8ae360>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d8ae590>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d8aeae0>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d8aef90>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d897270>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d897590>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d897680>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d897d10>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d897f40>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d8b23b0>, <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d8b2770>]

# %%
season_2024[0]
# Out:
# <Element '{http://ergast.com/mrd/1.5}Race' at 0x11d79d0e0>

# %%
season_2024[0].attrib
# Out:
# {'season': '2024',
#  'round': '1',
#  'url': 'https://en.wikipedia.org/wiki/2024_Bahrain_Grand_Prix'}

# %%
season_2024[0].attrib.get('round')
# Out:
# '1'

# %%
season_2024[0].attrib['season']
# Out:
# '2024'

# %%
season_2024[0].find('mrd:RaceName', ns).text
# Out:
# 'Bahrain Grand Prix'

# %%
season_2024[0].find('mrd:RaceName', ns)
# Out:
# <Element '{http://ergast.com/mrd/1.5}RaceName' at 0x11d79dc70>

# %%
season_2024[0].find('mrd:Circuit', ns).attrib.get('circuitId')
# Out:
# 'bahrain'

# %%
season_2024[0].find('mrd:Circuit', ns).attrib['url']
# Out:
# 'http://en.wikipedia.org/wiki/Bahrain_International_Circuit'

# %%
season_2024[0].find('mrd:Circuit', ns).find('mrd:CircuitName', ns)
# Out:
# <Element '{http://ergast.com/mrd/1.5}CircuitName' at 0x11d79d2c0>

# %%
circuit = season_2024[0].find('mrd:Circuit', ns)
circuit.find('mrd:CircuitName', ns).text
# Out:
# 'Bahrain International Circuit'

# %%
season_2024[0].find('mrd:Circuit', ns).find('mrd:CircuitName', ns).text
# Out:
# 'Bahrain International Circuit'

# %%
season_2024[0].find('mrd:Circuit', ns).find('mrd:Location', ns).attrib['lat']
# Out:
# '26.0325'

# %%
season_2024[0].find('mrd:Circuit', ns).find('mrd:Location', ns).attrib['long']
# Out:
# '50.5106'

# %%
season_2024[0].find('mrd:Circuit', ns).find('mrd:Location', ns).find('mrd:Locality', ns).text
# Out:
# 'Sakhir'

# %%
url = "http://ergast.com/api/f1/2024"
# Make a GET request to the Ergast API
response = requests.get(url)
# Check if the request was successful
if response.status_code == 200:
    # Parse the XML response
    root = ET.fromstring(response.content)
    # Define the namespace
    ns = {'mrd': 'http://ergast.com/mrd/1.5'}
    # Find all seasons elements
    season_2024 = root.findall('.//mrd:Race', ns)
    # Check if seasons were found
    if season_2024:
        # Extract data for each race
        for race in season_2024:
            race_round = race.attrib.get('round')
            season_year = race.attrib['season']
            race_name = race.find('mrd:RaceName', ns).text
            circuit = race.find('mrd:Circuit', ns)
            circuit_id = circuit.attrib['circuitId']
            circuit_information = circuit.attrib['url']
            circuit_name = circuit.find('mrd:CircuitName', ns).text
            location = circuit.find('mrd:Location', ns)
            locality = location.find('mrd:Locality', ns).text
            latitude = location.attrib['lat']
            longitude = location.attrib['long']
            country = circuit.find('mrd:Location/mrd:Country', ns).text
            race_information = race.attrib['url']
            date = race.find('mrd:Date', ns).text
            
            
            print(f"Race Round: {race_round}")
            print(f"Year: {season_year}")
            print(f"Circuit: {circuit}")
            print(f"Circuit Name: {circuit_name}")
            print(f"Locality: {locality}")
            print(f"Country: {country}")
            print(f"Latitude: {latitude}")
            print(f"Longitude: {longitude}")
            print(f"Race Information: {race_information}")
            print(f"Date: {date}")
            print("---")
    else:
        print("No seasons found. Check the XML structure and namespace.")
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# Race Round: 1
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d837bd0>
# Circuit Name: Bahrain International Circuit
# Locality: Sakhir
# Country: Bahrain
# Latitude: 26.0325
# Longitude: 50.5106
# Race Information: https://en.wikipedia.org/wiki/2024_Bahrain_Grand_Prix
# Date: 2024-03-02
# ---
# Race Round: 2
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8b2b30>
# Circuit Name: Jeddah Corniche Circuit
# Locality: Jeddah
# Country: Saudi Arabia
# Latitude: 21.6319
# Longitude: 39.1044
# Race Information: https://en.wikipedia.org/wiki/2024_Saudi_Arabian_Grand_Prix
# Date: 2024-03-09
# ---
# Race Round: 3
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8b5310>
# Circuit Name: Albert Park Grand Prix Circuit
# Locality: Melbourne
# Country: Australia
# Latitude: -37.8497
# Longitude: 144.968
# Race Information: https://en.wikipedia.org/wiki/2024_Australian_Grand_Prix
# Date: 2024-03-24
# ---
# Race Round: 4
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8b5630>
# Circuit Name: Suzuka Circuit
# Locality: Suzuka
# Country: Japan
# Latitude: 34.8431
# Longitude: 136.541
# Race Information: https://en.wikipedia.org/wiki/2024_Japanese_Grand_Prix
# Date: 2024-04-07
# ---
# Race Round: 5
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8b5900>
# Circuit Name: Shanghai International Circuit
# Locality: Shanghai
# Country: China
# Latitude: 31.3389
# Longitude: 121.22
# Race Information: https://en.wikipedia.org/wiki/2024_Chinese_Grand_Prix
# Date: 2024-04-21
# ---
# Race Round: 6
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8b5c20>
# Circuit Name: Miami International Autodrome
# Locality: Miami
# Country: USA
# Latitude: 25.9581
# Longitude: -80.2389
# Race Information: https://en.wikipedia.org/wiki/2024_Miami_Grand_Prix
# Date: 2024-05-05
# ---
# Race Round: 7
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8b5f40>
# Circuit Name: Autodromo Enzo e Dino Ferrari
# Locality: Imola
# Country: Italy
# Latitude: 44.3439
# Longitude: 11.7167
# Race Information: https://en.wikipedia.org/wiki/2024_Emilia_Romagna_Grand_Prix
# Date: 2024-05-19
# ---
# Race Round: 8
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8632c0>
# Circuit Name: Circuit de Monaco
# Locality: Monte-Carlo
# Country: Monaco
# Latitude: 43.7347
# Longitude: 7.42056
# Race Information: https://en.wikipedia.org/wiki/2024_Monaco_Grand_Prix
# Date: 2024-05-26
# ---
# Race Round: 9
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8635e0>
# Circuit Name: Circuit Gilles Villeneuve
# Locality: Montreal
# Country: Canada
# Latitude: 45.5
# Longitude: -73.5228
# Race Information: https://en.wikipedia.org/wiki/2024_Canadian_Grand_Prix
# Date: 2024-06-09
# ---
# Race Round: 10
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d863900>
# Circuit Name: Circuit de Barcelona-Catalunya
# Locality: Montmeló
# Country: Spain
# Latitude: 41.57
# Longitude: 2.26111
# Race Information: https://en.wikipedia.org/wiki/2024_Spanish_Grand_Prix
# Date: 2024-06-23
# ---
# Race Round: 11
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d863c20>
# Circuit Name: Red Bull Ring
# Locality: Spielberg
# Country: Austria
# Latitude: 47.2197
# Longitude: 14.7647
# Race Information: https://en.wikipedia.org/wiki/2024_Austrian_Grand_Prix
# Date: 2024-06-30
# ---
# Race Round: 12
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d863ef0>
# Circuit Name: Silverstone Circuit
# Locality: Silverstone
# Country: UK
# Latitude: 52.0786
# Longitude: -1.01694
# Race Information: https://en.wikipedia.org/wiki/2024_British_Grand_Prix
# Date: 2024-07-07
# ---
# Race Round: 13
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d865270>
# Circuit Name: Hungaroring
# Locality: Budapest
# Country: Hungary
# Latitude: 47.5789
# Longitude: 19.2486
# Race Information: https://en.wikipedia.org/wiki/2024_Hungarian_Grand_Prix
# Date: 2024-07-21
# ---
# Race Round: 14
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d865540>
# Circuit Name: Circuit de Spa-Francorchamps
# Locality: Spa
# Country: Belgium
# Latitude: 50.4372
# Longitude: 5.97139
# Race Information: https://en.wikipedia.org/wiki/2024_Belgian_Grand_Prix
# Date: 2024-07-28
# ---
# Race Round: 15
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d865860>
# Circuit Name: Circuit Park Zandvoort
# Locality: Zandvoort
# Country: Netherlands
# Latitude: 52.3888
# Longitude: 4.54092
# Race Information: https://en.wikipedia.org/wiki/2024_Dutch_Grand_Prix
# Date: 2024-08-25
# ---
# Race Round: 16
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d865b80>
# Circuit Name: Autodromo Nazionale di Monza
# Locality: Monza
# Country: Italy
# Latitude: 45.6156
# Longitude: 9.28111
# Race Information: https://en.wikipedia.org/wiki/2024_Italian_Grand_Prix
# Date: 2024-09-01
# ---
# Race Round: 17
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d865ea0>
# Circuit Name: Baku City Circuit
# Locality: Baku
# Country: Azerbaijan
# Latitude: 40.3725
# Longitude: 49.8533
# Race Information: https://en.wikipedia.org/wiki/2024_Azerbaijan_Grand_Prix
# Date: 2024-09-15
# ---
# Race Round: 18
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8c6220>
# Circuit Name: Marina Bay Street Circuit
# Locality: Marina Bay
# Country: Singapore
# Latitude: 1.2914
# Longitude: 103.864
# Race Information: https://en.wikipedia.org/wiki/2024_Singapore_Grand_Prix
# Date: 2024-09-22
# ---
# Race Round: 19
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8c6540>
# Circuit Name: Circuit of the Americas
# Locality: Austin
# Country: USA
# Latitude: 30.1328
# Longitude: -97.6411
# Race Information: https://en.wikipedia.org/wiki/2024_United_States_Grand_Prix
# Date: 2024-10-20
# ---
# Race Round: 20
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8c6860>
# Circuit Name: Autódromo Hermanos Rodríguez
# Locality: Mexico City
# Country: Mexico
# Latitude: 19.4042
# Longitude: -99.0907
# Race Information: https://en.wikipedia.org/wiki/2024_Mexico_City_Grand_Prix
# Date: 2024-10-27
# ---
# Race Round: 21
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8c6ae0>
# Circuit Name: Autódromo José Carlos Pace
# Locality: São Paulo
# Country: Brazil
# Latitude: -23.7036
# Longitude: -46.6997
# Race Information: https://en.wikipedia.org/wiki/2024_S%C3%A3o_Paulo_Grand_Prix
# Date: 2024-11-03
# ---
# Race Round: 22
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8c6db0>
# Circuit Name: Las Vegas Strip Street Circuit
# Locality: Las Vegas
# Country: United States
# Latitude: 36.1147
# Longitude: -115.173
# Race Information: https://en.wikipedia.org/wiki/2024_Las_Vegas_Grand_Prix
# Date: 2024-11-23
# ---
# Race Round: 23
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8c8130>
# Circuit Name: Losail International Circuit
# Locality: Al Daayen
# Country: Qatar
# Latitude: 25.49
# Longitude: 51.4542
# Race Information: https://en.wikipedia.org/wiki/2024_Qatar_Grand_Prix
# Date: 2024-12-01
# ---
# Race Round: 24
# Year: 2024
# Circuit: <Element '{http://ergast.com/mrd/1.5}Circuit' at 0x11d8c8450>
# Circuit Name: Yas Marina Circuit
# Locality: Abu Dhabi
# Country: UAE
# Latitude: 24.4672
# Longitude: 54.6031
# Race Information: https://en.wikipedia.org/wiki/2024_Abu_Dhabi_Grand_Prix
# Date: 2024-12-08
# ---

# %%
url = "http://ergast.com/api/f1/2024"  # Replace with your actual URL

# Make the GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Get the Content-Type header from the response
    content_type = response.headers.get('Content-Type')

    # Check if the response is JSON
    if 'application/json' in content_type:
        print("The response is in JSON format.")
        data = response.json()
        # Process the JSON data
    # Check if the response is XML
    elif 'application/xml' in content_type or 'text/xml' in content_type:
        print("The response is in XML format.")
        data = response.text  # XML data as string
        # Process the XML data
    else:
        print(f"Unknown content type: {content_type}")
else:
    print(f"Failed to retrieve data: {response.status_code}")
